# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as mk
import pandas as ms

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
w=ms.read_csv("C:/Users/ADMIN/Downloads/sachin_perfomance.csv")

# %%
w
# Out:
#      Unnamed: 0  Unnamed: 0.1  runs mins   BF  4s  6s     SR  Pos Dismissal  \
# 0             0             0    15   28   24   2   0   62.5    6    bowled
# 1             1             2    59  254  172   4   0   34.3    6       lbw
# 2             2             3     8   24   16   1   0     50    6    runout
# 3             3             4    41  124   90   5   0  45.55    7    bowled
# 4             4             5    35   74   51   5   0  68.62    6       lbw
# ..          ...           ...   ...  ...  ...  ..  ..    ...  ...       ...
# 777         777           806    21   71   23   2   0   91.3    4    runout
# 778         778           807    32   99   53   5   0  60.37    4       lbw
# 779         779           808     1    8    5   0   0     20    4       lbw
# 780         780           809    10   41   24   2   0  41.66    4       lbw
# 781         781           810    74  150  118  12   0  62.71    4    caught
#
# ...

# %%
w.shape
# Out:
# (782, 16)

# %%
w.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  runs mins   BF 4s  6s     SR  Pos Dismissal  \
# 0           0             0    15   28   24  2   0   62.5    6    bowled
# 1           1             2    59  254  172  4   0   34.3    6       lbw
# 2           2             3     8   24   16  1   0     50    6    runout
# 3           3             4    41  124   90  5   0  45.55    7    bowled
# 4           4             5    35   74   51  5   0  68.62    6       lbw
#
#    Inns  opponent      ground       date match  total
# 0     2  Pakistan     Karachi  15-Nov-89  Test     15
# 1     1  Pakistan  Faisalabad  23-Nov-89  Test     74
# 2     3  Pakistan  Faisalabad  23-Nov-89  Test     82
# 3     1  Pakistan      Lahore  01-Dec-89  Test    123
# 4     1  Pakistan     Sialkot  09-Dec-89  Test    158

# %%
w.tail()
# Out:
#      Unnamed: 0  Unnamed: 0.1  runs mins   BF  4s  6s     SR  Pos Dismissal  \
# 777         777           806    21   71   23   2   0   91.3    4    runout
# 778         778           807    32   99   53   5   0  60.37    4       lbw
# 779         779           808     1    8    5   0   0     20    4       lbw
# 780         780           809    10   41   24   2   0  41.66    4       lbw
# 781         781           810    74  150  118  12   0  62.71    4    caught
#
#      Inns    opponent    ground       date match  total
# 777     4   Australia    Mohali  14-Mar-13  Test  34240
# 778     2   Australia     Delhi  22-Mar-13  Test  34272
# 779     4   Australia     Delhi  22-Mar-13  Test  34273
# 780     2  WestIndies   Kolkata  06-Nov-13  Test  34283
# 781     2  WestIndies  Wankhede  14-Nov-13  Test  34357

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    782 non-null    int64
#  1   Unnamed: 0.1  782 non-null    int64
#  2   runs          782 non-null    int64
#  3   mins          782 non-null    object
#  4   BF            782 non-null    object
#  5   4s            782 non-null    object
#  6   6s            782 non-null    int64
#  7   SR            782 non-null    object
#  8   Pos           782 non-null    int64
#  9   Dismissal     782 non-null    object
#  10  Inns          782 non-null    int64
#  11  opponent      782 non-null    object
#  12  ground        782 non-null    object
#  13  date          782 non-null    object
#  14  match         782 non-null    object
#  15  total         782 non-null    int64
# dtypes: int64(7), object(9)
# memory usage: 97.9+ KB

# %%
dat=w.drop(['Unnamed: 0','Unnamed: 0.1','mins','BF','4s','6s','Pos','Dismissal','Inns','opponent','ground','date','match','total'],axis=1)

# %%
dat
# Out:
#      runs     SR
# 0      15   62.5
# 1      59   34.3
# 2       8     50
# 3      41  45.55
# 4      35  68.62
# ..    ...    ...
# 777    21   91.3
# 778    32  60.37
# 779     1     20
# 780    10  41.66
# 781    74  62.71
#
# [782 rows x 2 columns]

# %%
x=dat.iloc[:,0].values.reshape(-1,1)
y=dat.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[ 15],
#        [ 59],
#        [  8],
#        [ 41],
#        [ 35],
#        [ 57],
#        [  0],
#        [  0],
#        [ 24],
#        [ 88],
#        [  5],
#        [  0],
#        [ 36],
#        [ 10],
#        [ 20],
#        [ 19],
#        [ 31],
#        [ 10],
#        [ 27],
#        [ 68],
#        [119],
#        [ 21],
#        [ 11],
#        [ 36],
#        [ 53],
#        [ 30],
#        [  4],
#        [ 53],
#        [ 52],
#        [ 22],
#        [ 11],
#        [ 49],
#        [  0],
#        [ 62],
#        [  4],
#        [  1],
#        [ 16],
#        [  7],
#        [  1],
#        [ 36],
#        [ 57],
#        [ 48],
#        [ 21],
#        [ 15],
#        [ 40],
#        [148],
#        [ 77],
#        [ 31],
#        [ 57],
#        [  4],
#        [ 69],
#        [  6],
#        [ 17],
#        [114],
#        [  5],
#        [ 35],
#        [ 11],
#        [ 54],
#        [ 81],
#        [  4],
#        [ 84],
#        [ 14],
# ...

# %%
y
# Out:
# array([['62.5'],
#        ['34.3'],
#        ['50'],
#        ['45.55'],
#        ['68.62'],
#        ['42.53'],
#        ['0'],
#        ['0'],
#        ['54.54'],
#        ['33.08'],
#        ['38.46'],
#        ['0'],
#        ['92.3'],
#        ['83.33'],
#        ['80'],
#        ['54.28'],
#        ['119.23'],
#        ['52.63'],
#        ['41.53'],
#        ['50'],
#        ['62.96'],
#        ['70'],
#        ['-'],
#        ['163.63'],
#        ['129.26'],
#        ['103.44'],
#        ['36.36'],
#        ['75.71'],
#        ['130'],
#        ['81.48'],
#        ['40.74'],
#        ['128.94'],
#        ['0'],
#        ['84.93'],
#        ['50'],
#        ['33.33'],
#        ['38.09'],
#        ['28'],
#        ['11.11'],
#        ['55.38'],
#        ['53.27'],
#        ['84.21'],
#        ['60'],
#        ['65.21'],
#        ['37.38'],
#        ['69.48'],
#        ['60.62'],
#        ['70.45'],
#        ['64.77'],
#        ['40'],
#        ['69'],
#        ['75'],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)

# %%
x_train.shape
# Out:
# (703, 1)

# %%
x_test.shape
# Out:
# (79, 1)

# %%
y_train.shape
# Out:
# (703, 1)

# %%
y_test.shape
# Out:
# (79, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[ 54.2610845 ],
#        [ 52.41940855],
#        [ 72.67784407],
#        [ 51.10392572],
#        [ 54.52418107],
#        [ 51.10392572],
#        [ 65.83733337],
#        [ 53.47179481],
#        [ 58.99682268],
#        [ 58.20753298],
#        [ 51.36702229],
#        [ 81.09693415],
#        [ 78.72906506],
#        [ 58.20753298],
#        [ 65.31114024],
#        [ 68.99449215],
#        [ 70.30997498],
#        [102.14465936],
#        [ 63.46946429],
#        [ 77.93977537],
#        [ 55.8396639 ],
#        [ 80.04454789],
#        [ 59.25991924],
#        [ 78.99216163],
#        [ 81.88622385],
#        [ 58.47062955],
#        [ 57.41824329],
#        [ 63.99565742],
#        [ 59.52301581],
#        [ 94.51485897],
#        [ 59.25991924],
#        [ 51.10392572],
#        [103.72323876],
#        [ 56.10276046],
#        [ 56.10276046],
#        [ 51.36702229],
#        [ 53.99798794],
#        [ 97.14582463],
#        [ 55.31347077],
#        [ 51.89321542],
# ...

# %%
co=ms.DataFrame(x_test,columns=['list'])

# %%
co
# Out:
#     list
# 0     12
# 1      5
# 2     82
# 3      0
# 4     13
# ..   ...
# 74    24
# 75    24
# 76    86
# 77    36
# 78     5
#
# [79 rows x 1 columns]

# %%
co['availabe data']=y_test

# %%
co
# Out:
#     list availabe data
# 0     12            40
# 1      5         29.41
# 2     82        167.34
# 3      0             0
# 4     13            50
# ..   ...           ...
# 74    24            75
# 75    24          92.3
# 76    86         90.52
# 77    36        163.63
# 78     5         83.33
#
# [79 rows x 2 columns]

# %%
plt.plot(x_test,color='red')
plt.plot(y_predict,color='blue')
plt.show()

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 917.1255098318388

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 22.61324479349832

# %%
r2_score(y_test,y_predict)
# Out:
# 0.1696009579822213

# %%
plt()
